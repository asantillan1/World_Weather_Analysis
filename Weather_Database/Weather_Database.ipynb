# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Weather Description": city_desc,
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | peniche
# Processing Record 3 of Set 1 | ji-parana
# City not found. Skipping...
# Processing Record 4 of Set 1 | nikolskoye
# Processing Record 5 of Set 1 | ugoofaaru
# Processing Record 6 of Set 1 | sao joao da barra
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | lebanon
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 1 | talnakh
# Processing Record 19 of Set 1 | pechora
# Processing Record 20 of Set 1 | nioro
# Processing Record 21 of Set 1 | montepuez
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | san patricio
# Processing Record 25 of Set 1 | saldanha
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | nome
# Processing Record 28 of Set 1 | razole
# Processing Record 29 of Set 1 | havelock
# Processing Record 30 of Set 1 | kosonsoy
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | kaitangata
# Processing Record 34 of Set 1 | rikitea
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | bambous virieux
# Processing Record 37 of Set 1 | oranjemund
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | lazaro cardenas
# Processing Record 43 of Set 1 | oga
# Processing Record 44 of Set 1 | samarai
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | lavrentiya
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | dikson
# Processing Record 50 of Set 1 | mahajanga
# Processing Record 1 of Set 2 | lubyany
# Processing Record 2 of Set 2 | quelimane
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | guerrero negro
# Processing Record 5 of Set 2 | jumla
# Processing Record 6 of Set 2 | klaksvik
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | seoul
# Processing Record 9 of Set 2 | olafsvik
# Processing Record 10 of Set 2 | camacari
# Processing Record 11 of Set 2 | saint-philippe
# Processing Record 12 of Set 2 | yerbogachen
# Processing Record 13 of Set 2 | tabou
# Processing Record 14 of Set 2 | fort nelson
# Processing Record 15 of Set 2 | lerwick
# Processing Record 16 of Set 2 | saint-pierre
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | neiafu
# Processing Record 19 of Set 2 | tena
# Processing Record 20 of Set 2 | ponta do sol
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 2 | luderitz
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | meulaboh
# Processing Record 27 of Set 2 | coihaique
# Processing Record 28 of Set 2 | srednekolymsk
# Processing Record 29 of Set 2 | stephenville
# Processing Record 30 of Set 2 | sorland
# Processing Record 31 of Set 2 | acapulco
# Processing Record 32 of Set 2 | clyde river
# Processing Record 33 of Set 2 | hovd
# Processing Record 34 of Set 2 | lebu
# Processing Record 35 of Set 2 | karlskrona
# Processing Record 36 of Set 2 | carauari
# Processing Record 37 of Set 2 | honiara
# Processing Record 38 of Set 2 | talwara
# Processing Record 39 of Set 2 | crestview
# Processing Record 40 of Set 2 | mana
# Processing Record 41 of Set 2 | tiszakarad
# Processing Record 42 of Set 2 | victoria
# Processing Record 43 of Set 2 | fomboni
# Processing Record 44 of Set 2 | port blair
# Processing Record 45 of Set 2 | arraial do cabo
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | okhotsk
# Processing Record 49 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 50 of Set 2 | lulea
# Processing Record 1 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 3 | saint anthony
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | pochutla
# Processing Record 6 of Set 3 | xai-xai
# Processing Record 7 of Set 3 | iralaya
# Processing Record 8 of Set 3 | tevriz
# Processing Record 9 of Set 3 | murree
# Processing Record 10 of Set 3 | san cristobal
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | chokurdakh
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | vardo
# Processing Record 15 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 3 | yiyang
# Processing Record 18 of Set 3 | vila
# Processing Record 19 of Set 3 | filingue
# Processing Record 20 of Set 3 | bolgatanga
# Processing Record 21 of Set 3 | medicine hat
# Processing Record 22 of Set 3 | marystown
# Processing Record 23 of Set 3 | narsaq
# Processing Record 24 of Set 3 | lagoa
# Processing Record 25 of Set 3 | bethel
# Processing Record 26 of Set 3 | mandapam
# Processing Record 27 of Set 3 | bereda
# Processing Record 28 of Set 3 | anaco
# Processing Record 29 of Set 3 | vilyuysk
# Processing Record 30 of Set 3 | faanui
# Processing Record 31 of Set 3 | thinadhoo
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | bathsheba
# Processing Record 34 of Set 3 | georgetown
# Processing Record 35 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 36 of Set 3 | beira
# Processing Record 37 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 3 | malatya
# Processing Record 39 of Set 3 | kasimov
# Processing Record 40 of Set 3 | berlevag
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | minas novas
# Processing Record 43 of Set 3 | pisco
# Processing Record 44 of Set 3 | torbay
# Processing Record 45 of Set 3 | karratha
# Processing Record 46 of Set 3 | teahupoo
# Processing Record 47 of Set 3 | saint george
# Processing Record 48 of Set 3 | carnarvon
# Processing Record 49 of Set 3 | mount gambier
# Processing Record 50 of Set 3 | pyapon
# Processing Record 1 of Set 4 | sitka
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | airai
# Processing Record 4 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 5 of Set 4 | atsiki
# City not found. Skipping...
# Processing Record 6 of Set 4 | necochea
# Processing Record 7 of Set 4 | leshukonskoye
# Processing Record 8 of Set 4 | hilo
# Processing Record 9 of Set 4 | agadez
# Processing Record 10 of Set 4 | port elizabeth
# Processing Record 11 of Set 4 | mahur
# Processing Record 12 of Set 4 | buenos aires
# Processing Record 13 of Set 4 | yatou
# Processing Record 14 of Set 4 | ahipara
# Processing Record 15 of Set 4 | cururupu
# Processing Record 16 of Set 4 | palmer
# Processing Record 17 of Set 4 | aklavik
# Processing Record 18 of Set 4 | jamestown
# Processing Record 19 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 4 | ifanadiana
# Processing Record 21 of Set 4 | saint-augustin
# Processing Record 22 of Set 4 | fenoarivo
# Processing Record 23 of Set 4 | tautira
# Processing Record 24 of Set 4 | verkhnevilyuysk
# Processing Record 25 of Set 4 | moyale
# Processing Record 26 of Set 4 | thompson
# Processing Record 27 of Set 4 | port hardy
# Processing Record 28 of Set 4 | kahului
# Processing Record 29 of Set 4 | beloha
# Processing Record 30 of Set 4 | naze
# Processing Record 31 of Set 4 | nyurba
# Processing Record 32 of Set 4 | ilheus
# Processing Record 33 of Set 4 | namatanai
# Processing Record 34 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 4 | salalah
# Processing Record 36 of Set 4 | ukiah
# Processing Record 37 of Set 4 | east london
# Processing Record 38 of Set 4 | barcelos
# Processing Record 39 of Set 4 | lake charles
# Processing Record 40 of Set 4 | isla aguada
# Processing Record 41 of Set 4 | hasaki
# Processing Record 42 of Set 4 | praia da vitoria
# Processing Record 43 of Set 4 | laguna
# Processing Record 44 of Set 4 | sur
# Processing Record 45 of Set 4 | rabo de peixe
# Processing Record 46 of Set 4 | kavieng
# Processing Record 47 of Set 4 | avera
# Processing Record 48 of Set 4 | rassvet
# Processing Record 49 of Set 4 | andrews
# Processing Record 50 of Set 4 | ilulissat
# Processing Record 1 of Set 5 | niono
# Processing Record 2 of Set 5 | xining
# Processing Record 3 of Set 5 | lalganj
# Processing Record 4 of Set 5 | plettenberg bay
# Processing Record 5 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 5 | maloy
# Processing Record 7 of Set 5 | pascagoula
# Processing Record 8 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 5 | nhulunbuy
# Processing Record 10 of Set 5 | caravelas
# Processing Record 11 of Set 5 | ohara
# Processing Record 12 of Set 5 | richards bay
# Processing Record 13 of Set 5 | masuguru
# Processing Record 14 of Set 5 | tilichiki
# Processing Record 15 of Set 5 | tabas
# Processing Record 16 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 17 of Set 5 | tura
# Processing Record 18 of Set 5 | san quintin
# Processing Record 19 of Set 5 | alofi
# Processing Record 20 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 21 of Set 5 | safakulevo
# Processing Record 22 of Set 5 | wakkanai
# Processing Record 23 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 24 of Set 5 | burns lake
# Processing Record 25 of Set 5 | svetlogorsk
# Processing Record 26 of Set 5 | manono
# Processing Record 27 of Set 5 | upernavik
# Processing Record 28 of Set 5 | takoradi
# Processing Record 29 of Set 5 | thanh hoa
# Processing Record 30 of Set 5 | longyearbyen
# Processing Record 31 of Set 5 | pingliang
# Processing Record 32 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 33 of Set 5 | los banos
# Processing Record 34 of Set 5 | eydhafushi
# Processing Record 35 of Set 5 | deputatskiy
# Processing Record 36 of Set 5 | raga
# Processing Record 37 of Set 5 | muslyumovo
# Processing Record 38 of Set 5 | ramotswa
# Processing Record 39 of Set 5 | nalut
# Processing Record 40 of Set 5 | pacifica
# Processing Record 41 of Set 5 | la palma
# Processing Record 42 of Set 5 | saint-louis
# Processing Record 43 of Set 5 | macamic
# Processing Record 44 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 5 | college
# Processing Record 46 of Set 5 | gat
# Processing Record 47 of Set 5 | mount isa
# Processing Record 48 of Set 5 | tuktoyaktuk
# Processing Record 49 of Set 5 | leningradskiy
# Processing Record 50 of Set 5 | anadyr
# Processing Record 1 of Set 6 | grand-santi
# Processing Record 2 of Set 6 | popondetta
# Processing Record 3 of Set 6 | el alto
# Processing Record 4 of Set 6 | conde
# Processing Record 5 of Set 6 | cidreira
# Processing Record 6 of Set 6 | lagos
# Processing Record 7 of Set 6 | saskylakh
# Processing Record 8 of Set 6 | half moon bay
# Processing Record 9 of Set 6 | nueva loja
# Processing Record 10 of Set 6 | khash
# Processing Record 11 of Set 6 | sepolno krajenskie
# Processing Record 12 of Set 6 | inuvik
# Processing Record 13 of Set 6 | fairbanks
# Processing Record 14 of Set 6 | uitenhage
# Processing Record 15 of Set 6 | pirgos
# Processing Record 16 of Set 6 | kolno
# Processing Record 17 of Set 6 | lodja
# Processing Record 18 of Set 6 | faya
# Processing Record 19 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 6 | kazerun
# Processing Record 21 of Set 6 | guilin
# Processing Record 22 of Set 6 | bilma
# Processing Record 23 of Set 6 | henties bay
# Processing Record 24 of Set 6 | hay river
# Processing Record 25 of Set 6 | aleksandrovskoye
# Processing Record 26 of Set 6 | bien hoa
# Processing Record 27 of Set 6 | vanimo
# Processing Record 28 of Set 6 | bonavista
# Processing Record 29 of Set 6 | isangel
# Processing Record 30 of Set 6 | narrabri
# Processing Record 31 of Set 6 | dicabisagan
# Processing Record 32 of Set 6 | sibolga
# Processing Record 33 of Set 6 | grand baie
# Processing Record 34 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 35 of Set 6 | rocha
# Processing Record 36 of Set 6 | kavaratti
# Processing Record 37 of Set 6 | souillac
# Processing Record 38 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 6 | mucuri
# Processing Record 40 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 6 | killybegs
# Processing Record 42 of Set 6 | labuhan
# Processing Record 43 of Set 6 | balsas
# Processing Record 44 of Set 6 | hithadhoo
# Processing Record 45 of Set 6 | kanevskaya
# Processing Record 46 of Set 6 | muana
# Processing Record 47 of Set 6 | ribeira grande
# Processing Record 48 of Set 6 | ialibu
# Processing Record 49 of Set 6 | manoel urbano
# Processing Record 50 of Set 6 | hakvik
# City not found. Skipping...
# Processing Record 1 of Set 7 | saint-georges
# Processing Record 2 of Set 7 | pevek
# Processing Record 3 of Set 7 | sao filipe
# Processing Record 4 of Set 7 | erdenet
# Processing Record 5 of Set 7 | wladyslawowo
# Processing Record 6 of Set 7 | flin flon
# Processing Record 7 of Set 7 | hofn
# Processing Record 8 of Set 7 | nantucket
# Processing Record 9 of Set 7 | crateus
# Processing Record 10 of Set 7 | bone
# Processing Record 11 of Set 7 | mulege
# Processing Record 12 of Set 7 | brasilia de minas
# Processing Record 13 of Set 7 | grand-bourg
# Processing Record 14 of Set 7 | kailua
# Processing Record 15 of Set 7 | kidal
# Processing Record 16 of Set 7 | maldonado
# Processing Record 17 of Set 7 | srivardhan
# Processing Record 18 of Set 7 | vagur
# Processing Record 19 of Set 7 | solnechnyy
# Processing Record 20 of Set 7 | phuket
# Processing Record 21 of Set 7 | koslan
# Processing Record 22 of Set 7 | panaba
# Processing Record 23 of Set 7 | taltal
# Processing Record 24 of Set 7 | tharad
# Processing Record 25 of Set 7 | songkhla
# Processing Record 26 of Set 7 | paragominas
# Processing Record 27 of Set 7 | sortavala
# Processing Record 28 of Set 7 | los llanos de aridane
# Processing Record 29 of Set 7 | bathurst
# Processing Record 30 of Set 7 | boddam
# Processing Record 31 of Set 7 | mahebourg
# Processing Record 32 of Set 7 | bud
# Processing Record 33 of Set 7 | freistadt
# Processing Record 34 of Set 7 | asau
# Processing Record 35 of Set 7 | schwerin
# Processing Record 36 of Set 7 | morgan city
# Processing Record 37 of Set 7 | tete
# Processing Record 38 of Set 7 | jimenez
# Processing Record 39 of Set 7 | alta floresta
# Processing Record 40 of Set 7 | allapalli
# Processing Record 41 of Set 7 | turochak
# Processing Record 42 of Set 7 | kharitonovo
# Processing Record 43 of Set 7 | batagay-alyta
# Processing Record 44 of Set 7 | iqaluit
# Processing Record 45 of Set 7 | ancud
# Processing Record 46 of Set 7 | fukue
# Processing Record 47 of Set 7 | provideniya
# Processing Record 48 of Set 7 | muzhi
# Processing Record 49 of Set 7 | grand gaube
# Processing Record 50 of Set 7 | dawlatabad
# Processing Record 1 of Set 8 | cascais
# Processing Record 2 of Set 8 | mbour
# Processing Record 3 of Set 8 | campbell river
# Processing Record 4 of Set 8 | pimentel
# Processing Record 5 of Set 8 | ornskoldsvik
# Processing Record 6 of Set 8 | namibe
# Processing Record 7 of Set 8 | sribne
# Processing Record 8 of Set 8 | coahuayana
# Processing Record 9 of Set 8 | ipixuna
# Processing Record 10 of Set 8 | raudeberg
# Processing Record 11 of Set 8 | nanortalik
# Processing Record 12 of Set 8 | kuytun
# Processing Record 13 of Set 8 | wenling
# Processing Record 14 of Set 8 | faenza
# Processing Record 15 of Set 8 | hurghada
# Processing Record 16 of Set 8 | kruisfontein
# Processing Record 17 of Set 8 | belem de sao francisco
# Processing Record 18 of Set 8 | bambanglipuro
# Processing Record 19 of Set 8 | meadow lake
# Processing Record 20 of Set 8 | izumo
# Processing Record 21 of Set 8 | morant bay
# Processing Record 22 of Set 8 | tahe
# Processing Record 23 of Set 8 | bosaso
# Processing Record 24 of Set 8 | tateyama
# Processing Record 25 of Set 8 | wiang sa
# Processing Record 26 of Set 8 | lorengau
# Processing Record 27 of Set 8 | pueblo bello
# Processing Record 28 of Set 8 | asfi
# Processing Record 29 of Set 8 | morondava
# Processing Record 30 of Set 8 | dakar
# Processing Record 31 of Set 8 | alekseyevskoye
# Processing Record 32 of Set 8 | shorapur
# Processing Record 33 of Set 8 | havoysund
# Processing Record 34 of Set 8 | sangmelima
# Processing Record 35 of Set 8 | ajaccio
# Processing Record 36 of Set 8 | aguimes
# Processing Record 37 of Set 8 | sioux lookout
# Processing Record 38 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 8 | sangar
# Processing Record 40 of Set 8 | vieques
# Processing Record 41 of Set 8 | aykhal
# Processing Record 42 of Set 8 | waipawa
# Processing Record 43 of Set 8 | langerwehe
# Processing Record 44 of Set 8 | roald
# Processing Record 45 of Set 8 | aloleng
# Processing Record 46 of Set 8 | udachnyy
# Processing Record 47 of Set 8 | shenjiamen
# Processing Record 48 of Set 8 | paita
# Processing Record 49 of Set 8 | kholodnyy
# Processing Record 50 of Set 8 | lamu
# Processing Record 1 of Set 9 | kutum
# Processing Record 2 of Set 9 | harper
# Processing Record 3 of Set 9 | inhambane
# Processing Record 4 of Set 9 | kadiri
# Processing Record 5 of Set 9 | sorong
# Processing Record 6 of Set 9 | sisimiut
# Processing Record 7 of Set 9 | ambon
# Processing Record 8 of Set 9 | young
# Processing Record 9 of Set 9 | gushikawa
# Processing Record 10 of Set 9 | tromso
# Processing Record 11 of Set 9 | humaita
# Processing Record 12 of Set 9 | bandiagara
# Processing Record 13 of Set 9 | whakatane
# Processing Record 14 of Set 9 | talcahuano
# Processing Record 15 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 16 of Set 9 | corrales
# Processing Record 17 of Set 9 | kerki
# City not found. Skipping...
# Processing Record 18 of Set 9 | verkhnyaya inta
# Processing Record 19 of Set 9 | wervik
# Processing Record 20 of Set 9 | abha
# Processing Record 21 of Set 9 | flinders
# Processing Record 22 of Set 9 | guadalupe y calvo
# Processing Record 23 of Set 9 | eldikan
# City not found. Skipping...
# Processing Record 24 of Set 9 | yulara
# Processing Record 25 of Set 9 | severo-kurilsk
# Processing Record 26 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 9 | athabasca
# Processing Record 28 of Set 9 | linden
# Processing Record 29 of Set 9 | pitimbu
# Processing Record 30 of Set 9 | kologriv
# Processing Record 31 of Set 9 | orbottyan
# Processing Record 32 of Set 9 | warri
# Processing Record 33 of Set 9 | chumikan
# Processing Record 34 of Set 9 | lethem
# Processing Record 35 of Set 9 | kununurra
# Processing Record 36 of Set 9 | ballina
# Processing Record 37 of Set 9 | neryungri
# Processing Record 38 of Set 9 | sholapur
# Processing Record 39 of Set 9 | sao sebastiao
# Processing Record 40 of Set 9 | lakes entrance
# Processing Record 41 of Set 9 | mahon
# Processing Record 42 of Set 9 | komsomolskiy
# Processing Record 43 of Set 9 | lexington
# Processing Record 44 of Set 9 | bubaque
# Processing Record 45 of Set 9 | dan khun thot
# Processing Record 46 of Set 9 | codrington
# Processing Record 47 of Set 9 | san andres
# Processing Record 48 of Set 9 | tevaitoa
# Processing Record 49 of Set 9 | mitsamiouli
# Processing Record 50 of Set 9 | bengkulu
# Processing Record 1 of Set 10 | tiznit
# Processing Record 2 of Set 10 | teguldet
# Processing Record 3 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 4 of Set 10 | macia
# Processing Record 5 of Set 10 | sakete
# Processing Record 6 of Set 10 | ostrovnoy
# Processing Record 7 of Set 10 | turukhansk
# Processing Record 8 of Set 10 | manhattan
# Processing Record 9 of Set 10 | kenai
# Processing Record 10 of Set 10 | nuuk
# Processing Record 11 of Set 10 | tuatapere
# Processing Record 12 of Set 10 | lata
# Processing Record 13 of Set 10 | xiaoweizhai
# Processing Record 14 of Set 10 | ballitoville
# Processing Record 15 of Set 10 | erzin
# Processing Record 16 of Set 10 | kingman
# Processing Record 17 of Set 10 | garoua
# Processing Record 18 of Set 10 | healesville
# Processing Record 19 of Set 10 | bilibino
# Processing Record 20 of Set 10 | aquiraz
# Processing Record 21 of Set 10 | orlik
# Processing Record 22 of Set 10 | suzaka
# Processing Record 23 of Set 10 | muscat
# Processing Record 24 of Set 10 | gotsu
# Processing Record 25 of Set 10 | bay roberts
# Processing Record 26 of Set 10 | chauk
# Processing Record 27 of Set 10 | mobaye
# Processing Record 28 of Set 10 | iwanai
# Processing Record 29 of Set 10 | noshiro
# Processing Record 30 of Set 10 | kukmor
# Processing Record 31 of Set 10 | gerash
# Processing Record 32 of Set 10 | santa rosa
# Processing Record 33 of Set 10 | ilhabela
# Processing Record 34 of Set 10 | sawankhalok
# Processing Record 35 of Set 10 | shubarkuduk
# Processing Record 36 of Set 10 | gisborne
# Processing Record 37 of Set 10 | hecun
# Processing Record 38 of Set 10 | port arthur
# Processing Record 39 of Set 10 | vestmannaeyjar
# Processing Record 40 of Set 10 | agadir
# Processing Record 41 of Set 10 | igrim
# Processing Record 42 of Set 10 | dogondoutchi
# Processing Record 43 of Set 10 | starobachaty
# Processing Record 44 of Set 10 | llanes
# Processing Record 45 of Set 10 | hobyo
# Processing Record 46 of Set 10 | north bend
# Processing Record 47 of Set 10 | camacha
# Processing Record 48 of Set 10 | hvammstangi
# City not found. Skipping...
# Processing Record 49 of Set 10 | durban
# Processing Record 50 of Set 10 | hualmay
# Processing Record 1 of Set 11 | whitianga
# Processing Record 2 of Set 11 | darhan
# Processing Record 3 of Set 11 | comodoro rivadavia
# Processing Record 4 of Set 11 | khonsa
# Processing Record 5 of Set 11 | romitan
# Processing Record 6 of Set 11 | touros
# Processing Record 7 of Set 11 | batticaloa
# Processing Record 8 of Set 11 | sumbe
# Processing Record 9 of Set 11 | store heddinge
# Processing Record 10 of Set 11 | higuey
# City not found. Skipping...
# Processing Record 11 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 11 | pacific grove
# Processing Record 13 of Set 11 | piraquara
# Processing Record 14 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 11 | la libertad
# Processing Record 16 of Set 11 | sawtell
# Processing Record 17 of Set 11 | beringovskiy
# Processing Record 18 of Set 11 | miri
# Processing Record 19 of Set 11 | tongzhou
# Processing Record 20 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 11 | marsala
# Processing Record 22 of Set 11 | soyo
# Processing Record 23 of Set 11 | basco
# Processing Record 24 of Set 11 | terrace
# Processing Record 25 of Set 11 | pontianak
# Processing Record 26 of Set 11 | bang saphan
# Processing Record 27 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 28 of Set 11 | caconda
# Processing Record 29 of Set 11 | abu kamal
# Processing Record 30 of Set 11 | katha
# City not found. Skipping...
# Processing Record 31 of Set 11 | lasa
# Processing Record 32 of Set 11 | fare
# Processing Record 33 of Set 11 | kismayo
# Processing Record 34 of Set 11 | nemuro
# Processing Record 35 of Set 11 | llandrindod wells
# Processing Record 36 of Set 11 | kinablangan
# Processing Record 37 of Set 11 | shunyi
# Processing Record 38 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 11 | mao
# Processing Record 40 of Set 11 | pilna
# Processing Record 41 of Set 11 | saint-joseph
# Processing Record 42 of Set 11 | vila velha
# Processing Record 43 of Set 11 | golubitskaya
# Processing Record 44 of Set 11 | narsingdi
# Processing Record 45 of Set 11 | port macquarie
# Processing Record 46 of Set 11 | spas-klepiki
# Processing Record 47 of Set 11 | nikolayevsk-na-amure
# Processing Record 48 of Set 11 | hervey bay
# Processing Record 49 of Set 11 | nouakchott
# Processing Record 50 of Set 11 | cap-chat
# Processing Record 1 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 12 | betul
# Processing Record 3 of Set 12 | moose factory
# Processing Record 4 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 5 of Set 12 | idah
# Processing Record 6 of Set 12 | eyl
# Processing Record 7 of Set 12 | trinidad
# Processing Record 8 of Set 12 | rumoi
# Processing Record 9 of Set 12 | leamington
# Processing Record 10 of Set 12 | kondinskoye
# Processing Record 11 of Set 12 | paka
# Processing Record 12 of Set 12 | simbahan
# Processing Record 13 of Set 12 | grindavik
# Processing Record 14 of Set 12 | serebryansk
# Processing Record 15 of Set 12 | sakakah
# Processing Record 16 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 12 | russell
# Processing Record 18 of Set 12 | rorvik
# Processing Record 19 of Set 12 | damaturu
# Processing Record 20 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 12 | altay
# Processing Record 22 of Set 12 | ust-nera
# Processing Record 23 of Set 12 | serik
# Processing Record 24 of Set 12 | barbosa ferraz
# Processing Record 25 of Set 12 | jalu
# Processing Record 26 of Set 12 | ponta delgada
# Processing Record 27 of Set 12 | uruzgan
# Processing Record 28 of Set 12 | leh
# Processing Record 29 of Set 12 | nisia floresta
# Processing Record 30 of Set 12 | am timan
# Processing Record 31 of Set 12 | pahrump
# Processing Record 32 of Set 12 | volosovo
# Processing Record 33 of Set 12 | three hills
# Processing Record 34 of Set 12 | boa esperanca
# Processing Record 35 of Set 12 | katsuura
# Processing Record 36 of Set 12 | muskegon
# Processing Record 37 of Set 12 | san buenaventura
# Processing Record 38 of Set 12 | burgas
# Processing Record 39 of Set 12 | tukrah
# Processing Record 40 of Set 12 | mercedes
# Processing Record 41 of Set 12 | tadine
# Processing Record 42 of Set 12 | zhongshu
# Processing Record 43 of Set 12 | usinsk
# Processing Record 44 of Set 12 | goundam
# Processing Record 45 of Set 12 | velykoploske
# Processing Record 46 of Set 12 | trelew
# Processing Record 47 of Set 12 | helena
# Processing Record 48 of Set 12 | eirunepe
# Processing Record 49 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 12 | hendek
# Processing Record 1 of Set 13 | port lincoln
# Processing Record 2 of Set 13 | alausi
# Processing Record 3 of Set 13 | cabra
# Processing Record 4 of Set 13 | ylivieska
# Processing Record 5 of Set 13 | ambilobe
# Processing Record 6 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 7 of Set 13 | zyryanka
# Processing Record 8 of Set 13 | taikang
# Processing Record 9 of Set 13 | lanzhou
# Processing Record 10 of Set 13 | walvis bay
# Processing Record 11 of Set 13 | burica
# City not found. Skipping...
# Processing Record 12 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 13 | dingle
# Processing Record 14 of Set 13 | barcelona
# Processing Record 15 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 13 | katangli
# Processing Record 18 of Set 13 | zhanakorgan
# Processing Record 19 of Set 13 | kalabagh
# Processing Record 20 of Set 13 | daru
# Processing Record 21 of Set 13 | gloucester
# Processing Record 22 of Set 13 | haines junction
# Processing Record 23 of Set 13 | san juan
# Processing Record 24 of Set 13 | newton stewart
# Processing Record 25 of Set 13 | vila franca do campo
# Processing Record 26 of Set 13 | praia
# Processing Record 27 of Set 13 | ndioum
# Processing Record 28 of Set 13 | putyatino
# Processing Record 29 of Set 13 | zarubino
# Processing Record 30 of Set 13 | zaterechnyy
# Processing Record 31 of Set 13 | riviere-au-renard
# Processing Record 32 of Set 13 | belmonte
# Processing Record 33 of Set 13 | kearney
# Processing Record 34 of Set 13 | dungarvan
# Processing Record 35 of Set 13 | arlit
# Processing Record 36 of Set 13 | sao felix do xingu
# Processing Record 37 of Set 13 | esperance
# Processing Record 38 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 39 of Set 13 | abu dhabi
# Processing Record 40 of Set 13 | houston
# Processing Record 41 of Set 13 | carbonia
# Processing Record 42 of Set 13 | peto
# Processing Record 43 of Set 13 | baherden
# Processing Record 44 of Set 13 | paamiut
# Processing Record 45 of Set 13 | guarapari
# Processing Record 46 of Set 13 | husavik
# Processing Record 47 of Set 13 | novosergiyevka
# Processing Record 48 of Set 13 | coquimbo
# Processing Record 49 of Set 13 | spornoye
# Processing Record 50 of Set 13 | kourou
# Processing Record 1 of Set 14 | riyadh
# Processing Record 2 of Set 14 | krasnogorskoye
# Processing Record 3 of Set 14 | ambovombe
# Processing Record 4 of Set 14 | vao
# Processing Record 5 of Set 14 | portland
# Processing Record 6 of Set 14 | pokrovsk
# Processing Record 7 of Set 14 | cazaje
# City not found. Skipping...
# Processing Record 8 of Set 14 | semey
# Processing Record 9 of Set 14 | baghdad
# Processing Record 10 of Set 14 | livingstone
# Processing Record 11 of Set 14 | nampula
# Processing Record 12 of Set 14 | ust-kuyga
# Processing Record 13 of Set 14 | punta gorda
# Processing Record 14 of Set 14 | christchurch
# Processing Record 15 of Set 14 | kieta
# Processing Record 16 of Set 14 | kinanah
# City not found. Skipping...
# Processing Record 17 of Set 14 | soyaniquilpan
# Processing Record 18 of Set 14 | kawalu
# Processing Record 19 of Set 14 | klichka
# Processing Record 20 of Set 14 | saint-paul
# Processing Record 21 of Set 14 | tongchuan
# Processing Record 22 of Set 14 | magdalena
# Processing Record 23 of Set 14 | kyra
# Processing Record 24 of Set 14 | prainha
# Processing Record 25 of Set 14 | adrar
# Processing Record 26 of Set 14 | buala
# Processing Record 27 of Set 14 | kibre mengist
# Processing Record 28 of Set 14 | lamar
# Processing Record 29 of Set 14 | iracoubo
# Processing Record 30 of Set 14 | sinnamary
# Processing Record 31 of Set 14 | ixcatepec
# Processing Record 32 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 14 | dayong
# Processing Record 34 of Set 14 | krutaya gorka
# Processing Record 35 of Set 14 | uthal
# Processing Record 36 of Set 14 | pimenta bueno
# Processing Record 37 of Set 14 | safford
# Processing Record 38 of Set 14 | marzuq
# Processing Record 39 of Set 14 | kalmunai
# Processing Record 40 of Set 14 | virginia beach
# Processing Record 41 of Set 14 | sereflikochisar
# Processing Record 42 of Set 14 | fortuna
# Processing Record 43 of Set 14 | valladolid
# Processing Record 44 of Set 14 | omis
# Processing Record 45 of Set 14 | garceni
# Processing Record 46 of Set 14 | lima
# Processing Record 47 of Set 14 | presidencia roque saenz pena
# Processing Record 48 of Set 14 | emerald
# Processing Record 49 of Set 14 | acarau
# Processing Record 50 of Set 14 | peleduy
# Processing Record 1 of Set 15 | ghanzi
# Processing Record 2 of Set 15 | baikunthpur
# Processing Record 3 of Set 15 | cabo san lucas
# Processing Record 4 of Set 15 | owo
# Processing Record 5 of Set 15 | kurchum
# Processing Record 6 of Set 15 | esqueda
# Processing Record 7 of Set 15 | black forest
# Processing Record 8 of Set 15 | galesong
# Processing Record 9 of Set 15 | finschhafen
# Processing Record 10 of Set 15 | brandenburg
# Processing Record 11 of Set 15 | mweka
# Processing Record 12 of Set 15 | the valley
# Processing Record 13 of Set 15 | hede
# Processing Record 14 of Set 15 | baie-comeau
# Processing Record 15 of Set 15 | gazli
# Processing Record 16 of Set 15 | gamba
# Processing Record 17 of Set 15 | gondanglegi
# Processing Record 18 of Set 15 | cayenne
# Processing Record 19 of Set 15 | kupang
# Processing Record 20 of Set 15 | aberdeen
# Processing Record 21 of Set 15 | wanxian
# Processing Record 22 of Set 15 | narok
# Processing Record 23 of Set 15 | buenaventura
# Processing Record 24 of Set 15 | shimoda
# Processing Record 25 of Set 15 | sampit
# Processing Record 26 of Set 15 | cayhagan
# Processing Record 27 of Set 15 | jalingo
# Processing Record 28 of Set 15 | carutapera
# Processing Record 29 of Set 15 | padang
# Processing Record 30 of Set 15 | nishihara
# Processing Record 31 of Set 15 | wanning
# Processing Record 32 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 15 | verkhoyansk
# Processing Record 34 of Set 15 | mayo
# Processing Record 35 of Set 15 | erenhot
# Processing Record 36 of Set 15 | korfovskiy
# Processing Record 37 of Set 15 | margate
# Processing Record 38 of Set 15 | desbiens
# Processing Record 39 of Set 15 | nevers
# Processing Record 40 of Set 15 | yarmouth
# Processing Record 41 of Set 15 | turan
# Processing Record 42 of Set 15 | isiro
# Processing Record 43 of Set 15 | la ronge
# Processing Record 44 of Set 15 | trenggalek
# Processing Record 45 of Set 15 | senanga
# Processing Record 46 of Set 15 | washington
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Mataura      NZ -46.1927  168.8643     73.92        36
# 1            Peniche      PT  39.3558   -9.3811     61.61        94
# 2         Nikolskoye      RU  59.7035   30.7861     28.02        82
# 3          Ugoofaaru      MV   5.6667   73.0000     80.60        81
# 4  Sao Joao Da Barra      BR -21.6403  -41.0511     71.76        80
# 5          Busselton      AU -33.6500  115.3333     65.05        46
# 6            Ushuaia      AR -54.8000  -68.3000     46.06        71
# 7              Bluff      NZ -46.6000  168.3333     62.28        63
# 8             Atuona      PF  -9.8000 -139.0333     77.77        79
# 9            Qaanaaq      GL  77.4840  -69.3632      3.15        57
#
#    Cloudiness  Wind Speed Weather Description
# 0         100        4.09     overcast clouds
# 1          96        6.80     overcast clouds
# 2          11        6.62          few clouds
# 3          99       11.48     overcast clouds
# 4         100        4.21     overcast clouds
# 5          58       14.34       broken clouds
# 6          20        3.44          few clouds
# 7         100        6.44     overcast clouds
# 8          15       16.91          light rain
# 9           0        9.62           clear sky

# %%
# Create CSV file of DF
csv_weather_file = "WeatherPy_Database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
